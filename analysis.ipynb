# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_excel("gym_db.xlsx")

# %%
df[df['Year']==2023].head(150)
# Out:
#         Year     Month Week         Day                    Exercise Sets
# 2674  2023.0   January    1  Chest Back                 Bench press    3  \
# 2675  2023.0   January    1  Chest Back                    Pull ups    3
# 2676  2023.0   January    1  Chest Back           Cable flies lower    3
# 2677  2023.0   January    1  Chest Back               Machine flies    3
# 2678  2023.0   January    1  Chest Back                     DB rows    3
# ...      ...       ...  ...         ...                         ...  ...
# 2819  2023.0  February    1  Chest Back            Incline DB press    3
# 2820  2023.0  February    1  Chest Back                    Lat pull  NaN
# 2821  2023.0  February    1  Chest Back           Cable flies upper    3
# 2822  2023.0  February    1  Chest Back                     DB rows    3
# 2823  2023.0  February    1  Chest Back  Rev flies SS rev peck deck    3
#
#          Reps Weight  Unnamed: 8
# 2674        3   67.5         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5701 entries, 0 to 5700
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        3458 non-null   float64
#  1   Month       3458 non-null   object
#  2   Week        3459 non-null   object
#  3   Day         3458 non-null   object
#  4   Exercise    3458 non-null   object
#  5   Sets        3364 non-null   object
#  6   Reps        3335 non-null   object
#  7   Weight      2800 non-null   object
#  8   Unnamed: 8  3 non-null      float64
# dtypes: float64(2), object(7)
# memory usage: 401.0+ KB

# %%
df.describe()
# Out:
#               Year  Unnamed: 8
# count  3458.000000    3.000000
# mean   2021.941874   14.000000
# std       0.725445    1.732051
# min    2021.000000   12.000000
# 25%    2021.000000   13.500000
# 50%    2022.000000   15.000000
# 75%    2022.000000   15.000000
# max    2023.000000   15.000000

# %%
df.head(100)
# Out:
#       Year Month Week   Day           Exercise Sets Reps Weight  Unnamed: 8
# 0   2021.0  June    1  Legs           BB Squat    3   12     30         NaN
# 1   2021.0  June    1  Legs                RDL    3   12     30         NaN
# 2   2021.0  June    1  Legs          Leg press    3   12    120         NaN
# 3   2021.0  June    1  Legs          Leg curls    3   18     18         NaN
# 4   2021.0  June    1  Legs      Leg extension    3   15     43         NaN
# ..     ...   ...  ...   ...                ...  ...  ...    ...         ...
# 95  2021.0  July    1  Pull    Bar bicep curls    3   15     21         NaN
# 96  2021.0  July    1  Pull  Hammer curls rope    3   15     30         NaN
# 97  2021.0  July    1  Legs           BB Squat    3   12     45         NaN
# 98  2021.0  July    1  Legs             RDL BB    3   12     35         NaN
# 99  2021.0  July    1  Legs          Leg press    3   10    175         NaN
#
# [100 rows x 9 columns]

# %%
df.drop(columns="Unnamed: 8",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5701 entries, 0 to 5700
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      3458 non-null   float64
#  1   Month     3458 non-null   object
#  2   Week      3459 non-null   object
#  3   Day       3458 non-null   object
#  4   Exercise  3458 non-null   object
#  5   Sets      3364 non-null   object
#  6   Reps      3335 non-null   object
#  7   Weight    2800 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 356.4+ KB

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#      Year Month Week   Day       Exercise Sets Reps Weight
# 0  2021.0  June    1  Legs       BB Squat    3   12     30
# 1  2021.0  June    1  Legs            RDL    3   12     30
# 2  2021.0  June    1  Legs      Leg press    3   12    120
# 3  2021.0  June    1  Legs      Leg curls    3   18     18
# 4  2021.0  June    1  Legs  Leg extension    3   15     43

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.head()
# Out:
#    Year Month Week   Day       Exercise Sets Reps Weight
# 0  2021  June    1  Legs       BB Squat    3   12     30
# 1  2021  June    1  Legs            RDL    3   12     30
# 2  2021  June    1  Legs      Leg press    3   12    120
# 3  2021  June    1  Legs      Leg curls    3   18     18
# 4  2021  June    1  Legs  Leg extension    3   15     43

# %%
df.replace('-', np.nan, inplace=True)

# %%
df.tail(100)
# Out:
#       Year Month  Week    Day         Exercise  Sets Reps  Weight
# 3311  2023   May     4  Sarms     Skullkrusher   3.0   12    17.5
# 3317  2023   May     4   Legs           Squats   3.0    5    97.5
# 3318  2023   May     4   Legs        Leg press   3.0   15   310.0
# 3319  2023   May     4   Legs   Leg press calf   3.0   15   120.0
# 3320  2023   May     4   Legs    Standing calf   3.0   10    50.0
# ...    ...   ...   ...    ...              ...   ...  ...     ...
# 3484  2023  June     4  Sarms     EZ bar curls   5.0   15    15.0
# 3489  2023  June     4  Sarms   Preacher curls   3.0   10    34.0
# 3490  2023  June     4   Legs           RDL DB   3.0   10    25.0
# 3491  2023  June     4   Legs    Leg extension   3.0   15    70.0
# 3492  2023  June     4   Legs  Standing Calves   3.0   15    40.0
#
# [100 rows x 8 columns]

# %%
#convert months to numbers 1-12

# %%
month_to_number = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12,
}

# Map month names to numbers using the dictionary
df['Month'] = df['Month'].map(month_to_number)

# %%
df[df['Year']==2023].head(150)
# Out:
#       Year  Month  Week         Day              Exercise  Sets Reps  Weight
# 2674  2023      1     1  Chest Back           Bench press   3.0    3    67.5
# 2675  2023      1     1  Chest Back              Pull ups   3.0   12     NaN
# 2676  2023      1     1  Chest Back     Cable flies lower   3.0   15    38.5
# 2677  2023      1     1  Chest Back         Machine flies   3.0   15    57.0
# 2678  2023      1     1  Chest Back               DB rows   3.0   15    20.0
# ...    ...    ...   ...         ...                   ...   ...  ...     ...
# 2892  2023      2     3       Sarms  Incline DB SS hammer   3.0   15    12.5
# 2895  2023      2     3        Legs              Deadlift   2.0    5   150.0
# 2897  2023      2     3        Legs                Calves   3.0   15    40.0
# 2898  2023      2     4  Chest Back           Bench press   3.0    6    70.0
# 2900  2023      2     4  Chest Back           Cable flies   3.0   15    36.0
#
# [150 rows x 8 columns]

# %%
df['Month'].replace(['NA', 'inf'], np.nan, inplace=True)

# Convert Month column to float
df['Month'] = df['Month'].astype(float)

# Convert float Month values to integers (1-12)
df['Month'] = df['Month'].astype(int)

# %%
df[df['Year']==2022].head(150)
# Out:
#       Year  Month  Week   Day            Exercise  Sets Reps  Weight
# 1044  2022      1     1  Push            BB BENCH   3.0    8    50.0
# 1045  2022      1     1  Push   Chest flies cable   3.0   15    30.0
# 1046  2022      1     1  Push   Chest fly machine   3.0   15    43.0
# 1047  2022      1     1  Push              DB OHP   3.0   12    17.5
# 1048  2022      1     1  Push      DBlateralraise   3.0   15    12.5
# ...    ...    ...   ...   ...                 ...   ...  ...     ...
# 1204  2022      2     1  Pull  Lat pull over rope   3.0   15    36.0
# 1205  2022      2     1  Pull   Pull down DB curl   3.0   15    10.0
# 1206  2022      2     1  Pull          Cable CUrl   3.0   20    36.0
# 1207  2022      2     1  Pull           Hammer DB   3.0   12    17.5
# 1208  2022      2     1  Pull       Rev peck deck   3.0   15    50.0
#
# [150 rows x 8 columns]

# %%
df['Sets'].replace(['NA', 'inf'], np.nan, inplace=True)
df['Sets'] = df['Sets'].astype(float)
df['Sets'] = df['Sets'].fillna(0).astype(int)

# %%
df.tail(100)
# Out:
#       Year  Month  Week    Day         Exercise  Sets Reps  Weight
# 3311  2023      5     4  Sarms     Skullkrusher     3   12    17.5
# 3317  2023      5     4   Legs           Squats     3    5    97.5
# 3318  2023      5     4   Legs        Leg press     3   15   310.0
# 3319  2023      5     4   Legs   Leg press calf     3   15   120.0
# 3320  2023      5     4   Legs    Standing calf     3   10    50.0
# ...    ...    ...   ...    ...              ...   ...  ...     ...
# 3484  2023      6     4  Sarms     EZ bar curls     5   15    15.0
# 3489  2023      6     4  Sarms   Preacher curls     3   10    34.0
# 3490  2023      6     4   Legs           RDL DB     3   10    25.0
# 3491  2023      6     4   Legs    Leg extension     3   15    70.0
# 3492  2023      6     4   Legs  Standing Calves     3   15    40.0
#
# [100 rows x 8 columns]

# %%
df['Day'].unique()
# Out:
# array(['Legs', 'Push', 'Pull', 'Chest Back', 'Sarms', 'UB'], dtype=object)

# %%
df['Exercise'].unique()
# Out:
# array(['BB Squat', 'RDL', 'Leg press', 'Leg curls', 'Leg extension',
#        'Seated calf raise', 'Flat BB press', 'Incline DB press',
#        'Chest flies cable', 'Seated DB OHP', 'Lateral raise',
#        'Tricep push down', 'OH extension DB', 'Deadlift',
#        'Cable rows seated', 'Lat pull down', 'EZ bar', 'Preacher',
#        'Hammer curls', 'Reverse peck deck machine',
#        'Bulgarian split squats DB', 'Decline BB press', 'Flat DB PRESS',
#        'Scoop machine', 'BB OHP', 'EZ bar Skull crusher',
#        'Weighted Bench dips', 'Incline dB curls', 'Supinate DB curls',
#        'Close grip to wide grip curls', 'RDL DB', 'Standing calf raise',
#        'Cable Lateral raise', 'Tricep rope push down',
#        'Cable rows seated supinated', 'Cable pullover',
#        'DB curls supinated', 'Hammer curls machine', 'Calf raise',
#        'Bar push down', 'Sumo deadlift', 'Machine rows',
#        'Incline bicep curls', 'Cable bicep curls', 'Hammer curls DB',
# ...

# %%
df['Exercise'].nunique()
# Out:
# 476

# %%
sbd_exercise_mapping = {
    'Squat': 'BB Squat',
    'BB SQUAT': 'BB Squat',
    'Squat BB': 'BB Squat',
    'Front Squat':'BB Squat',
    'BB pause Squat':'BB Squat',
    'Squats':'BB Squat',
    'Paused bench':'BB Bench Press',
    'Flat bench PRESS' : 'BB Bench Press',
    'BB BENCH' : 'BB Bench Press',
    'Flat bench':'BB Bench Press',
    'Flat Bench':'BB Bench Press',
    'Bench':'BB Bench Press',
    'Bench press':'BB Bench Press',
    'Paused Bench press':'BB Bench Press',
    'Flat BB press':'BB Bench Press',
    'Sumo deadlift':'Deadlift',
    'Conv deadlift':'Deadlift',
    'deadlift':'Deadlift',
    'Deadlift conv':'Deadlift',
    'Paused Deadlift':'Deadlift',
    'Paused deadlift':'Deadlift',
    'Deadlift paused':'Deadlift',
    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# Replace exercise names with standardized names using the mapping dictionary

# %%
df['Exercise'] = df['Exercise'].replace(sbd_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 456

# %%
pressing_exercise_mapping = {
    'Leg press':'Leg Press',
    'Incline DB press':'DB Incline Press',
    'Decline BB press':'BB Decline Press',
    'Flat DB PRESS':'DB Flat Press',
    'Incline DB PRESS':'DB Incline Press',
    'Incline DB press 1 hole':'DB Incline Press',
    'Close grip press':'BB Close Grip Press',
    'SL Leg Press':'Leg Press SL',
    'Chest press machine':'Machine Press',
    'Leg press calf raise':'Leg Press',
    'Flat DB press':'DB Flat Press',
    'Machine chest press':'Machine Press',
    'Chest machine press':'Machine Press',
    'Chest press':'Machine Press',
    'Machine press':'Machine Press',
    'Seated Leg press':'Leg Press',
    'Calf leg press':'Leg Press Calf',
    'Leg press calf':'Leg Press Calf',

    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(pressing_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 446

# %%
OH_exercise_mapping = {
    'Seated DB OHP':'DB Seated Overhead Press',
    'OH extension DB':'DB Overhead Extension',
    'BB OHP':'BB Overhead Press',
    'DB OHP':'DB Seated Overhead Press',
    'OH extension':'Cable Overhead Extension',
    'OHP DB':'DB Seated Overhead Press',
    'OH cable extension v bar':'Cable Overhead Extension',
    'OH CABLE EXT':'Cable Overhead Extension',
    'DB OHO':'DB Seated Overhead Press',
    'OH EXT':'Cable Overhead Extension',
    'DB OH ext':'DB Overhead Extension',
    'OH EXT cable':'Cable Overhead Extension',
    'OH EXT DB':'DB Overhead Extension',
    'OH EXT V':'Cable Overhead Extension',
    'OH EXT V bar':'Cable Overhead Extension',
    'OH EXT rope':'Cable Overhead Extension',
    'OH EXT v bar':'Cable Overhead Extension',
    'Tricep OH ext':'Cable Overhead Extension',
    'OH ext':'Cable Overhead Extension',
    'Rope OH ext':'Cable Overhead Extension',
    'Tricep OH EXT rope':'Cable Overhead Extension',
    'OH ext cable rope':'Cable Overhead Extension',
    'OH ext cable v bar':'Cable Overhead Extension',
    'SA OH EXT':'Cable Overhead Extension',
    'OHP BB':'BB Overhead Press',
    'OH ext rope':'Cable Overhead Extension',
    
    
    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(OH_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 424

# %%
smith_exercise_mapping = {
    'Smith machine OHP':'Smith Machine Overhead Press',
    'BSS Smith':'Bulgarian Split Squats Smith Machine',
    'Incline smith machine':'Smith Machine Incline Press',
    'BB OHP smith':'Smith Machine Overhead Press',
    'RDL BB smith machine':'Smith Machine RDL',
    'Incline Bench press smith machine':'Smith Machine Incline Press',
    'BB OHP smith machine':'Smith Machine Overhead Press'
    
    
    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(smith_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 421

# %%
curls_exercise_mapping = {
    'Leg curls' : 'Leg Curls',
    'Leg curl':'Leg Curls',
    'Hammer curls'  :'DB Hammer Curls',
    'Incline dB curls':'DB Incline Curls',
    'Supinate DB curls':'DB Curls',
    'Close grip to wide grip curls':'DB Curls',
    'DB curls supinated':'DB Curls',
    'Hammer curls machine':'DB Hammer Curls',
    'Incline bicep curls':'DB Incline Curls',
    'Cable bicep curls':'Cable Curls',
    'Hammer curls DB':'DB Hammer Curls',
    'Bar bicep curls':'EZ Bar Curls',
    'Hammer curls rope':'Rope Hammer Curls',
    'EZ Bar bicep curls close grip':'EZ Bar Curls',
    'Ez bar bicep curls':'EZ Bar Curls',
    'Mini bar bicep curls':'EZ Bar Curls',
    'Reverse grip curls cable':'EZ Bar Curls',
    'Forearm DB curls':'DB Forearm Curls',
    'Standing DB curls':'DB Curls',
    'Forearm curls DB':'DB Forearm Curls',
    'Incline DB curls':'DB Incline Curls',
    'Reverse grip cable curls':'Cable Reverse Grip Curls',
    'Incline DB bicep curls':'DB Incline Curls',
    'Hammer curls dB':'DB Hammer Curls',
    'Preacher curls':'Preacher Curls',
    'Ez bar curls':'EZ Bar Curls',
    'Mini bar curls':'EZ Bar Curls',
    'Incline Hammer curl': 'DB Incline Curls',
    'Reverse grip cable curl':'Cable Reverse Grip Curls',
    'Hammer curls ROPE':'Rope Hammer Curls',
    'Incline DB curl':'DB Incline Curls',
    'EZ BAR CURL':'EZ Bar Curls',
    'V bar cable curls':'Cable Curls',
    'V BAR CUrl':'Cable Curls',
    'Ez bar Cable CUrl':'Cable Curls',
    'EZ bar curls':'EZ Bar Curls',
    'Cable CUrl':'Cable Curls',
    'Seated EZ bar curls':'EZ Bar Curls',
    'Reverse cable curl':'Cable Reverse Grip Curls',
    'Forearm curls':'DB Forearm Curls',
    'Cable curls':'Cable Curls',
    'DB curls':'DB Curls',
    'Pull down DB curl':'DB Curls',
    'Pull down curls':'DB Curls',
    'Pulldown curls':'DB Curls',
    'Reverse curls cable':'Cable Reverse Grip Curls',
    'Standing DB curls':'DB Curls',
    'Concentrain curl':'Concentration Curls',
    'DB cable curl':'DB Curls',
    'DB short head curl':'DB Curls',
    'Rope hammer curls':'Rope Hammer Curls',
    'Incline cable curls':'Bayesian Curls',
    'Hammer curls standing':'DB Hammer Curls',
    'Seated Leg curl':'Leg Curls',
    'Long head cable curl':'Bayesian Curls',
    'Seated DB curl':'DB Curls',
    'Bicep curl machine':'DB Curls',
    'Hammer curls cable':'Cable Curls',
    'Cable curls ez bar':'Cable Curls',
    'Long head cable curls':'Bayesian Curls',
    'Incline Cable curls':'Bayesian Curls',
    'Spider curls ez bar':'EZ Bar Curls',
    'DB alt curl':'DB Curls',
    'Cable curl':'Cable Curls',
    'BB curls':'EZ Bar Curls',
    'Hammer curl DB':'DB Hammer Curls',
    'Alt curls':'DB Curls',
    'Hammer cable curls':'Rope Hammer Curls',
    'Straight bar curls':'EZ Bar Curls',
    'Preacher curl SA':'Preacher Curls',
    'EZ bar curls heavy':'EZ Bar Curls',
    'Leg curl SL':'Leg Curls',
    'Preacher curls SA':'Preacher Curls',
    'EZ bar spider curl':'EZ Bar Curls',
    'Revers cable curls':'Cable Reverse Grip Curls',
    'Spider curls ez bar':'EZ Bar Curls',
    'Reverse curls':'Cable Reverse Grip Curls',
    'Reverse EZ bar curls':'EZ Bar Reverse Curls',
    'Hammer Db curls':'DB Hammer Curls',
    'Face away curls cable':'Bayesian Curls',
    'Reverse EZ bar curl':'EZ Bar Reverse Curls',
    'Rope Hammer curls':'Rope Hammer Curls',
    'Ez bar reverse curls':'EZ Bar Reverse Curls',
    'Conc curl':'Concentration Curls',
    'BB curl':'EZ Bar Curls',
    'Hammer Curls':'DB Hammer Curls',
    'EZ bar rev curl':'EZ Bar Reverse Curls',
    'Hammer Curls heavy':'DB Hammer Curls',
    'Faceaway curls':'Bayesian Curls',
    'curls':'DB Curls',
    'Faceaway curls SA':'Bayesian Curls'

    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(curls_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 351

# %%
ss_exercise_mapping = {
    'Cable curls SS reverse curls':'Cable Curls SS Reverse Curls',
    'Cable curls SS Reverse cable curls':'Cable Curls SS Reverse Curls',
    'Incline DB curl SS hammer curl':'DB Incline Curls SS Hammer Curls',
    'OH Rope EXT SS pushdown':'Cable Overhead Extension SS Pushdown',
    'OH ext tricep cable SS facepuls':'Cable Overhead Extension SS Facepulls',
    'Ez bar curls close grip SS hammer DB':'EZ Bar Curls SS Hammer Curls',
    'Incline skill rusher ez bar SS Hammer DB':'Skullcrusher SS Hammer Curls',
    'Ez bar reverse curls SS normal curls':'EZ Bar Reverse Curls SS Curls',
    'OH cable ext SS Rope hammer':'Cable Overhead Extension SS Hammer Curls',
    'EZ bar curls close grip SS reverse curls':'EZ Bar Reverse Curls SS Curls',
    'EZ bar curl SS rev curl':'EZ Bar Reverse Curls SS Curls',
    'Rev EZ bar curls SS DB hammer':'EZ Bar Curls SS Hammer Curls',
    'Preacher curl SS conc curl':'Preacher Curls SS Conc Curls',
    'Tricep OH ext Ss pushdown':'Cable Overhead Extension SS Pushdown',
    'Facepulls SS Rope hammer':'Facepulls SS Hammer',
    'Incline DB curl SS hammer':'DB Incline Curls SS Hammer Curls',
    'Reverse curls SS hammer curls':'EZ Bar Curls SS Hammer Curls',
    'Incline DB curls SS DB hammer':'DB Incline Curls SS Hammer Curls',
    'Reverse EZ bar curl SS hammer DB':'EZ Bar Curls SS Hammer Curls',
    'Reverse curls EZ bar SS close grip curls':'EZ Bar Reverse Curls SS Curls',
    'skull crusher SS Hammer DB':'Skullcrusher SS Hammer Curls',
    'DB curls SS hammer':'DB Incline Curls SS Hammer Curls',
    'EZ bar rev curl SS normal curls':'EZ Bar Reverse Curls SS Curls',
    'DB curled SS hammer curls':'DB Incline Curls SS Hammer Curls',
    'Incline DB curls SS hammer':'DB Incline Curls SS Hammer Curls',
    'Preacher curls SS OH ext':'Preacher Curls SS Overhead Extension',
    'Incline DB SS hammer':'DB Incline Curls SS Hammer Curls',
    'Hammer curls SS OH ext':'DB Hammer Curls SS Overhead Extension',
    'Reverse curls SS normal curls':'EZ Bar Reverse Curls SS Curls',
    'Cable flies SS machine flies':'Cable Flies SS Machine Flies',
    'Hammer Curls SS preacher hammer':'Hammer SS Preacher Curls',
    'SA pushdown SS OH ext':'Cable Overhead Extension SS Pushdown',
    'Preacher curls SS OHext':'Preacher Curls SS Overhead Extension',
    'Skullkrusher SS preacher curls':'Preacher Curls SS Overhead Extension',
    'Skullkrusher SS hammer':'Skullcrusher SS Hammer Curls',
    'Incline DB SS hammer curls':'DB Incline Curls SS Hammer Curls',


    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(ss_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 330

# %%
leg_exercise_mapping = {
    'Leg Press':'Leg Press',
    'Leg extension':'Leg Extension',
    'Single Leg extension':'Leg Extension',
    'SL Leg extension':'Leg Extension',
    'SL Leg press':'Leg Press',
    'Leg ext':'Leg Extension',
    'Leg ext SL':'Leg Extension',
    'SL Leg ext':'Leg Extension',
    'Leg extension':'Leg Extension',
    'Legextension':'Leg Extension',
    'Leg extensions':'Leg Extension',
        
    
    # Add more mappings for other exercise names
    # 'Original Exercise Name': 'Standardized Exercise Name'
}

# %%
df['Exercise'] = df['Exercise'].replace(leg_exercise_mapping)

# %%
df['Exercise'].nunique()
# Out:
# 322

# %%
squats_df = df[df['Exercise']=='BB Squat']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the squat DataFrame by Year and Month, and calculate the mean of weights
Squat_Monthly = squats_df.groupby(['Year', 'Month'])['Weight'].mean().reset_index()

# Plot the grouped bar chart
sns.barplot(x='Month', y='Weight', hue='Year', data=Squat_Monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Average Squat Weight')
plt.title('Average Monthly Squat Weight Comparison by Year')

# Adjust the position of the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', ncol=1)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the squat DataFrame by Year and Month, and calculate the mean of weights
Squat_Monthly = squats_df.groupby(['Year', 'Month'])['Weight'].mean().reset_index()

# Plot the line plot
sns.lineplot(x='Month', y='Weight', hue='Year', data=Squat_Monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Average Squat Weight')
plt.title('Average Monthly Squat Weight Comparison by Year')

# Show the plot
plt.show()

# %%
squats_df
# Out:
#       Year  Month  Week   Day  Exercise  Sets     Reps  Weight
# 0     2021      6     1  Legs  BB Squat     3       12    30.0
# 22    2021      6     1  Legs  BB Squat     3       12    35.0
# 42    2021      6     2  Legs  BB Squat     3       12    40.0
# 97    2021      7     1  Legs  BB Squat     3       12    45.0
# 135   2021      7     2  Legs  BB Squat     3       10    50.0
# ...    ...    ...   ...   ...       ...   ...      ...     ...
# 3317  2023      5     4  Legs  BB Squat     3        5    97.5
# 3355  2023      6     1  Legs  BB Squat     3        8   100.0
# 3393  2023      6     2  Legs  BB Squat     3        5   105.0
# 3434  2023      6     3  Legs  BB Squat     3        5   105.0
# 3472  2023      6     4  Legs  BB Squat     3  failure   100.0
#
# [156 rows x 8 columns]

# %%
deads_df = df[df['Exercise']=='Deadlift']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the deadlift DataFrame by Year and Month, and calculate the sum of weights
deadlift_monthly = deads_df.groupby(['Year', 'Month'])['Weight'].mean().reset_index()

# Plot the grouped bar chart
sns.barplot(x='Month', y='Weight', hue='Year', data=deadlift_monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Total Deadlift Weight')
plt.title('Avg Monthly Deadlift Weight Comparison by Year')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Plot the line plot
sns.lineplot(x='Month', y='Weight', hue='Year', data=deadlift_monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Average Squat Weight')
plt.title('Average Monthly Deadlift Weight Comparison by Year')

# Show the plot
plt.show()

# %%
bench_df = df[df['Exercise']=='BB Bench Press']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the squat DataFrame by Year and Month, and calculate the mean of weights
bench_monthly = bench_df.groupby(['Year', 'Month'])['Weight'].mean().reset_index()

# Plot the grouped bar chart
sns.barplot(x='Month', y='Weight', hue='Year', data=bench_monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Average Bench Weight')
plt.title('Average Monthly Bench Weight Comparison by Year')

# Adjust the position of the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', ncol=1)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Plot the line plot
sns.lineplot(x='Month', y='Weight', hue='Year', data=bench_monthly)

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Average Squat Weight')
plt.title('Average Monthly Bench Press Weight Comparison by Year')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the DataFrame by Year and Day, and calculate the count
yearly_day_count = df.groupby(['Year', 'Day']).size().reset_index(name='Count')

# Plot the bar plot
sns.barplot(x='Day', y='Count', hue='Year', data=yearly_day_count)

# Set labels and title
plt.xlabel('Day')
plt.ylabel('Count')
plt.title('Number of Times Each Day Was Performed (By Year)')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the DataFrame by Day and Exercise, and calculate the count
exercise_count = df.groupby(['Day', 'Exercise']).size().reset_index(name='Count')

# Sort the exercise_count DataFrame by Count in descending order within each Day
exercise_count_sorted = exercise_count.groupby('Day').apply(lambda x: x.sort_values('Count', ascending=False)).reset_index(drop=True)

# Get the top 10 exercises for each day
top_10_exercises = exercise_count_sorted.groupby('Day').head(10)

# Plot the bar plots for each day
g = sns.FacetGrid(top_10_exercises, col='Day', col_wrap=3, height=4, sharey=False)
g.map(sns.barplot, 'Count', 'Exercise', palette='viridis', ci=None)
g.set_titles('{col_name}')
g.set_axis_labels('Count', 'Exercise')

# Adjust the spacing between subplots
plt.subplots_adjust(top=0.9, hspace=0.5)

# Set the overall title
plt.suptitle('Top 10 Exercises Performed for Each Day')

# Show the plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count occurrences of specific words in 'Exercise' column
bb_count = df['Exercise'].str.contains('BB', case=False).sum()
db_count = df['Exercise'].str.contains('DB', case=False).sum()
cable_count = df['Exercise'].str.contains('Cable', case=False).sum()

# Create a DataFrame for the counts
word_counts = pd.DataFrame({'Word': ['BB', 'DB', 'Cable'],
                            'Count': [bb_count, db_count, cable_count]})

# Plot the bar plot
sns.barplot(x='Word', y='Count', data=word_counts)

# Set labels and title
plt.xlabel('Word')
plt.ylabel('Count')
plt.title('Type of weights')

# Show the plot
plt.show()
